# %% [markdown]
# **Soal 1. Data Preparation**
#
# Bacalah Dataset dengan memberikan beberapa argumen sehingga bisa membaca datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('drive/MyDrive/Colab Notebooks/Tugas5Pekan2/climate_change.csv')
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0       1/1/2013  10.000000   84.500000    0.000000   1015.666667
# 1       1/2/2013   7.400000   92.000000    2.980000   1017.800000
# 2       1/3/2013   7.166667   87.000000    4.633333   1018.666667
# 3       1/4/2013   8.666667   71.333333    1.233333   1017.166667
# 4       1/5/2013   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  12/28/2016  17.217391   68.043478    3.547826   1015.565217
# 1458  12/29/2016  15.238095   87.857143    6.000000   1016.904762
# 1459  12/30/2016  14.095238   89.666667    6.266667   1017.904762
# 1460  12/31/2016  15.052632   87.000000    7.325000   1016.100000
# 1461    1/1/2017  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
#code here
df_climate = pd.read_csv('drive/MyDrive/Colab Notebooks/Tugas5Pekan2/climate_change.csv', index_col='date', parse_dates=True)
df_climate
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1TqrXs9JStRXqiF0NIWiMdo5r8CQ-S74-)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# Soal 2. Selection
#
# Tampilkan data keseluruhan untuk tahun 2015 di bulan November

# %%
#code here
df_climate['2015-11']
# Out:
# <ipython-input-11-ddb17db174a9>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_climate['2015-11']
#             meantemp  humidity  wind_speed  meanpressure
# date
# 2015-11-01    22.875    70.500      0.9250      1016.250
# 2015-11-02    23.375    71.375      0.4625      1015.875
# 2015-11-03    24.000    67.875      0.4750      1014.250
# 2015-11-04    23.750    69.000      0.9250      1012.250
# 2015-11-05    22.125    75.250      5.1000      1012.375
# 2015-11-06    22.875    74.375      2.3250      1012.750
# 2015-11-07    21.875    74.875      1.1625      1014.625
# 2015-11-08    21.875    70.250      1.8625      1015.875
# 2015-11-09    21.750    73.625      0.7000      1015.000
# 2015-11-10    22.750    72.625      0.7000      1013.500
# 2015-11-11    21.875    59.500      4.6375      1014.375
# ...

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1ABMLSmdQ817PIdxW1v7rUKelOj_W241g)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 3. Filtering**
#
# Tampilkan data perubahan iklim pada 1 bulan terakhir di tahun 2016 dan jawablah pertanyaan berikut:
#
# Berapakah rata-rata temperatur tertinggi?

# %%
#code here
df_climate['2016'].last('1M')
# Out:
# <ipython-input-22-4ea354df0897>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_climate['2016'].last('1M')
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-12-01  19.750000  84.000000    2.704167   1016.875000
# 2016-12-02  19.208333  75.875000    4.945833   1017.750000
# 2016-12-03  21.208333  52.166667    5.866667   1019.333333
# 2016-12-04  18.900000  55.250000    5.666667   1019.700000
# 2016-12-05  18.636364  56.590909    4.952381   1017.045455
# 2016-12-06  18.538462  69.923077    2.503846   1017.961538
# 2016-12-07  18.250000  74.350000    0.925000   1017.421053
# 2016-12-08  16.900000  73.300000    1.765000   1016.200000
# 2016-12-09  19.416667  68.125000    1.312500   1013.416667
# 2016-12-10  16.444444  82.833333    5.355556   1014.000000
# ...

# %%
df_climate['2016'].last('1M').agg({'meantemp':'max'})
# Out:
# <ipython-input-23-e3423dc0321c>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_climate['2016'].last('1M').agg({'meantemp':'max'})
# meantemp    21.208333
# dtype: float64

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1X2hXsvrRGvqHqtc5BFbVvRXwh5YxBQ_P)

# %% [markdown]
# Jawab disini: Berdasarkan tabel di atas, **rata-rata temperatur tinggi** pada bulan **Desember 2016** adalah **21.208333**

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 4. Time grouping**
#
#
#
# *   Lakukan grouping data perubahan iklim pada tahun 2016 berdasarkan frekuensi 1 bulan dengan memberikan agregasi max pada kolom meantemp. humidity, wind_speed dan meanpressure!
# *   Berikan analisa, di bulan apa rata-rata temperatur, humidity, wind_speed dan meanpressure tertinggi?

# %%
#code here
time_group = df_climate['2016'].groupby(pd.Grouper(freq='1M')).agg('max')
time_group
# Out:
# <ipython-input-26-61b33a7d3e1f>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   time_group = df_climate['2016'].groupby(pd.Grouper(freq='1M')).agg('max')
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-01-31  20.142857  88.833333   11.240000   1021.142857
# 2016-02-29  23.875000  77.000000   17.137500   1020.071429
# 2016-03-31  30.000000  67.800000   22.100000   7679.333333
# 2016-04-30  35.687500  44.250000   19.653846   1009.400000
# 2016-05-31  38.272727  74.812500   18.425000   1007.466667
# 2016-06-30  38.200000  75.071429   21.306250   1002.833333
# 2016-07-31  34.187500  93.875000   13.656250   1004.625000
# 2016-08-31  33.809524  89.555556   14.666667   1006.200000
# 2016-09-30  33.444444  87.240000   17.908333   1352.615385
# ...

# %%
time_group.describe()
# Out:
#         meantemp   humidity  wind_speed  meanpressure
# count  12.000000  12.000000   12.000000     12.000000
# mean   30.644760  78.724981   17.200717   1624.290999
# std     6.386197  13.988236    3.228020   1911.340199
# min    20.142857  44.250000   11.240000   1002.833333
# 25%    25.198750  74.078125   14.980417   1007.150000
# 50%    33.356838  78.543478   17.522917   1018.753846
# 75%    34.562500  89.013889   19.467033   1103.431217
# max    38.272727  94.300000   22.100000   7679.333333

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1s2Y8Dc3M3xbG-51mTuTmXUFgLvHDvc5Q)

# %% [markdown]
# Jawab disini:
# Berdasarkan data di atas, dengan asumsi data tersebut merupakan data dari negara dengan 2 musim seperti Indonesia, dapat ditarik kesimpulan sebagai berikut:
# * **meantemp** tertinggi pada tahun 2016 terjadi pada bulan Mei. Hal ini dikarenakan bulan Mei termasuk ke dalam musim kemarau. Umumnya suhu tertinggi terjadi pada awal mula musim kemarau setalah pancaroba dan atau menuju puncak musim kemarau. Gerak semu matahari, kelembaban yang menurun merupakan salah 2 dari banyak faktor yang dapat menyebabkan suhu meningkat.
# https://regional.kompas.com/read/2022/07/23/154321578/mengenal-2-jenis-musim-di-indonesia-musim-hujan-dan-musim-kemarau?page=all
# * **humidity** tertinggi pada tahun 2016 terjadi pada bulan Desember. Hal ini dikarenakan Desember termasuk kedalam musim penghujan. Kelembaban meningkat pada saat musim hujan daripada musim kemarau.
# https://dspace.hangtuah.ac.id/xmlui/bitstream/handle/dx/550/Pengaruh%20Musim%20%28Hujan%20dan%20Kemarau%29%20Terhadap%20Kepadatan%20populasi%20Larva%20Aedes%20Aegypti%20...pdf?sequence=3&isAllowed=y
# * **wind_speed & meanpressure** tertinggi pada tahun 2016 terjadi pada bulan Maret. Hal ini dikarenakan bulan Maret merupakan peralihan antara musim hujan ke musim kemarau atau yang biasa disebut dengan **Pancaroba**. Perbedaan suhu antara laut dan daratan menyebabkan perbedaan tekanan yang memicu aliran angin. Semakin besar perbedaan tekanan yang terjadi, angin yang dihasilkan pun akan semakin kencang yang umumnya terjadi di permukaan.
# https://news.republika.co.id/berita/r6tlh6428/bmkg-jelaskan-penyebab-angin-kencang-beberapa-pekan-ini#google_vignette
# https://ejournal.instiki.ac.id/index.php/sintechjournal/article/view/298

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Soal 5. Time Differenced**
#
# Tunjukkanlah perubahan iklim di tahun 2016 pada minggu terakhir

# %%
#code here
df_climate['2016'].last('1W').diff()
# Out:
# <ipython-input-31-19d37da57d70>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_climate['2016'].last('1W').diff()
#             meantemp   humidity  wind_speed  meanpressure
# date
# 2016-12-26       NaN        NaN         NaN           NaN
# 2016-12-27 -0.292857  -7.307143   -0.449211      0.247619
# 2016-12-28  0.367391   0.493478   -4.787174     -1.634783
# 2016-12-29 -1.979296  19.813665    2.452174      1.339545
# 2016-12-30 -1.142857   1.809524    0.266667      1.000000
# 2016-12-31  0.957393  -2.666667    1.058333     -1.804762

# %% [markdown]
# Expected output:
#
# (Gambar hanya sebagian)
#
# ![alt text](https://drive.google.com/uc?id=1miJBQeGMyUS_G3bwP14Plo4s5950oYy5)

# %% [markdown]
# ---
#
#
#
# ---
